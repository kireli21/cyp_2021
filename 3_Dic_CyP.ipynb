# %% [markdown]
# <a href="https://colab.research.google.com/github/kireli21/cyp_2021/blob/main/3_Dic_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ejemplo 1
for i in[1,2,3,4,5]:
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 4
# El elemento: 5

# %%
# Ejemplo 1.1
coleccion = [1,2,3,4,5]
for i in coleccion:
  print(f"El elemento: {i}")
# Out:
# El elemento: 1
# El elemento: 2
# El elemento: 3
# El elemento: 4
# El elemento: 5

# %%
# Ejemplo 2

coleccion = {"mario": 20, "Mariana": 19, "Yessica": 14, "louis": 18}
for i in coleccion:
  print(f"Elemento: {i}")
# Out:
# Elemento: mario
# Elemento: Mariana
# Elemento: Yessica
# Elemento: louis

# %%
coleccion = {"mario": 20, "Mariana": 19, "Yessica": 14, "louis": 18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion = {"mario": 20, "Mariana": 19, "Yessica": 14, "louis": 18}
for i in coleccion:
  print(f"{i}: {coleccion [i]}")
# Out:
# mario: 20
# Mariana: 19
# Yessica: 14
# louis: 18

# %%
coleccion = {"mario": 20, "Mariana": 19, "Yessica": 14, "louis": 18}

for clave, valor in coleccion.items():
  print(f"{clave}: {valor}")
# Out:
# mario: 20
# Mariana: 19
# Yessica: 14
# louis: 18

# %%
# Ejemplo 3

email = False
for i in "ariel@unam.mx":
  if i == "@":
    email = True
if email == True:
  print("el email es correcto")
else :
  print("el correo no es correcto")
# Out:
# el correo no es correcto

# %%
email = False
miemail = input("introduce tu correo: ")
for i in miemail:
  if i == "@":
    email = True
if email == True:
  print("el email es correcto")
else :
  print("el correo no es correcto")
# Out:
# introduce tu correo: karly21nwn@gmail.com
# el email es correcto

# %%
# For-range

for i in range (5):
  print(f"{i}")
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (34):
  print(f"el valor es: {i}")
# Out:
# el valor es: 0
# el valor es: 1
# el valor es: 2
# el valor es: 3
# el valor es: 4
# el valor es: 5
# el valor es: 6
# el valor es: 7
# el valor es: 8
# el valor es: 9
# el valor es: 10
# el valor es: 11
# el valor es: 12
# el valor es: 13
# el valor es: 14
# el valor es: 15
# el valor es: 16
# el valor es: 17
# el valor es: 18
# el valor es: 19
# el valor es: 20
# el valor es: 21
# el valor es: 22
# el valor es: 23
# el valor es: 24
# el valor es: 25
# el valor es: 26
# el valor es: 27
# el valor es: 28
# el valor es: 29
# el valor es: 30
# el valor es: 31
# el valor es: 32
# el valor es: 33

# %%
# While ejemplos
# Ejemplo1

i = 1
while i <= 10:
  print("Ejecucion " + str(i))
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# Ejecucion 1
# ...

# %%
i = 1
while i <= 10:
  print("Ejecucion " + str(i))
  i = i + 1
# Out:
# Ejecucion 1
# Ejecucion 2
# Ejecucion 3
# Ejecucion 4
# Ejecucion 5
# Ejecucion 6
# Ejecucion 7
# Ejecucion 8
# Ejecucion 9
# Ejecucion 10

# %%
edad = int(input("ingresa tu edad: "))
while edad < 0:
  print("Has introducido una edad negativa, Intentalo de nuevo")
  edad = int(input("ingresa tu edad: "))
print("gracias por participar, puede pasar")
print(f"edad del participante: {edad}")
# Out:
# ingresa tu edad: -9
# Has introducido una edad negativa, Intentalo de nuevo
# ingresa tu edad: -8
# Has introducido una edad negativa, Intentalo de nuevo
# ingresa tu edad: 5
# gracias por participar, puede pasar
# edad del participante: 5

# %%
edad = int(input("ingresa tu edad: "))
while edad >= 10 or edad >= 100:
  print("Has introducido una edad negativa, Intentalo de nuevo")
  edad = int(input("ingresa tu edad: "))
print("gracias por participar, puede pasar")
print(f"edad del participante: {edad}")
# Out:
# ingresa tu edad: 5
# gracias por participar, puede pasar
# edad del participante: 5
